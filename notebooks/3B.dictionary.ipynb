# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import geopandas as gpd 
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../") 

from utils.paths import make_dir_line

modality = 'u'
project = 'Ciencia de los datos'
data = make_dir_line(modality, project)

raw = data('raw')
processed = data('processed')

# %%
ter = pd.read_parquet(processed / 'ter.parquet.gzip')
ter.rename(columns={'Territory':'DEN_REG'}, inplace=True)
ter['DEN_REG'] = ter['DEN_REG'].str.title()
ter.head()
# Out:
#   ITTER107     DEN_REG
# 0       IT       Italy
# 2     ITCD        Nord
# 4      ITC  Nord-Ovest
# 6     ITC1    Piemonte
# 8    ITC11      Torino

# %%
chunk = pd.read_parquet(processed / 'chunk.parquet.gzip')
chunk.head()
# Out:
#   ITTER107  SEXISTAT1  Age  STATCIV2     Value
# 0       IT          1    0         1  205371.0
# 1       IT          2    0         1  195255.0
# 2     ITCD          1    0         1   94721.0
# 3     ITCD          2    0         1   89834.0
# 4      ITC          1    0         1   53931.0

# %%
geo = gpd.read_file(raw / "Limiti01012023_g/Reg01012023_g/Reg01012023_g_WGS84.shp")
geo.geometry = geo.geometry.to_crs(epsg = 4326)
geo.head()
# Out:
#    COD_RIP  COD_REG              DEN_REG    Shape_Leng    Shape_Area
# 0        1        1             Piemonte  1.236800e+06  2.539388e+10  \
# 1        1        2        Valle d'Aosta  3.109681e+05  3.258838e+09
# 2        1        3            Lombardia  1.410223e+06  2.386232e+10
# 3        2        4  Trentino-Alto Adige  8.008937e+05  1.360755e+10
# 4        2        5               Veneto  1.054587e+06  1.834355e+10
#
#                                             geometry
# 0  POLYGON ((8.44976 46.46176, 8.46176 46.45081, ...
# 1  POLYGON ((7.58857 45.97075, 7.58981 45.97073, ...
# 2  MULTIPOLYGON (((8.81642 45.02231, 8.81427 45.0...
# 3  POLYGON ((12.20511 47.08653, 12.20668 47.08627...
# 4  POLYGON ((12.50591 46.67839, 12.50603 46.67803...

# %%
geo.head(20)
# Out:
#     COD_RIP  COD_REG                DEN_REG    Shape_Leng    Shape_Area
# 0         1        1               Piemonte  1.236800e+06  2.539388e+10  \
# 1         1        2          Valle d'Aosta  3.109681e+05  3.258838e+09
# 2         1        3              Lombardia  1.410223e+06  2.386232e+10
# 3         2        4    Trentino-Alto Adige  8.008937e+05  1.360755e+10
# 4         2        5                 Veneto  1.054587e+06  1.834355e+10
# 5         2        6  Friuli Venezia Giulia  6.708207e+05  7.934116e+09
# 6         1        7                Liguria  8.196598e+05  5.414542e+09
# 7         2        8         Emilia-Romagna  1.180343e+06  2.249987e+10
# 8         3        9                Toscana  1.306243e+06  2.298404e+10
# 9         3       10                 Umbria  6.197684e+05  8.464380e+09
# 10        3       11                 Marche  6.170373e+05  9.343412e+09
# 11        3       12                  Lazio  1.054411e+06  1.722682e+10
# ...

# %%
lista_verificacion = geo['DEN_REG'].unique()
print(lista_verificacion)
# Out:
# ['Piemonte' "Valle d'Aosta" 'Lombardia' 'Trentino-Alto Adige' 'Veneto'
#  'Friuli Venezia Giulia' 'Liguria' 'Emilia-Romagna' 'Toscana' 'Umbria'
#  'Marche' 'Lazio' 'Abruzzo' 'Molise' 'Campania' 'Puglia' 'Basilicata'
#  'Calabria' 'Sicilia' 'Sardegna']

# %%
df_incluidos = ter[ter['DEN_REG'].isin(lista_verificacion)]
df_incluidos = df_incluidos[~df_incluidos['ITTER107'].str.match(r'^\d')]
df_incluidos.head()
# Out:
#    ITTER107        DEN_REG
# 6      ITC1       Piemonte
# 24     ITC2  Valle d'Aosta
# 26    ITC20  Valle d'Aosta
# 28     ITC3        Liguria
# 38     ITC4      Lombardia

# %%
df_incluidos.head(30)
# Out:
#     ITTER107                DEN_REG
# 6       ITC1               Piemonte
# 24      ITC2          Valle d'Aosta
# 26     ITC20          Valle d'Aosta
# 28      ITC3                Liguria
# 38      ITC4              Lombardia
# 64      ITDA    Trentino-Alto Adige
# 74      ITD3                 Veneto
# 90      ITD4  Friuli Venezia Giulia
# 100     ITD5         Emilia-Romagna
# 122     ITE1                Toscana
# 144     ITE2                 Umbria
# 150     ITE3                 Marche
# 160     ITE4                  Lazio
# 176     ITF1                Abruzzo
# 186     ITF2                 Molise
# 192     ITF3               Campania
# 204     ITF4                 Puglia
# 216     ITF5             Basilicata
# 222     ITF6               Calabria
# 236     ITG1                Sicilia
# 256     ITG2               Sardegna

# %%
df_incluidos.shape
# Out:
# (21, 2)

# %%
df_results = pd.merge(chunk, df_incluidos, on=['ITTER107'])
print(df_results.shape)
# Out:
# (25410, 6)

# %%
df_results.head()
# Out:
#   ITTER107  SEXISTAT1  Age  STATCIV2    Value   DEN_REG
# 0     ITC1          1    0         1  13729.0  Piemonte
# 1     ITC1          2    0         1  13029.0  Piemonte
# 2     ITC1          2    1         1  13240.0  Piemonte
# 3     ITC1          1    1         1  14131.0  Piemonte
# 4     ITC1          1    2         1  14501.0  Piemonte

# %%
df_results = df_results.loc[:,['ITTER107','DEN_REG','SEXISTAT1','Value']]
df_results = df_results.groupby(['ITTER107', 'DEN_REG', 'SEXISTAT1'], as_index=False).sum()
df_results.head()
# Out:
#   ITTER107        DEN_REG  SEXISTAT1      Value
# 0     ITC1       Piemonte          1  2073845.0
# 1     ITC1       Piemonte          2  2182505.0
# 2     ITC2  Valle d'Aosta          1    60413.0
# 3     ITC2  Valle d'Aosta          2    62947.0
# 4    ITC20  Valle d'Aosta          1    60413.0

# %%
print(df_results.shape, geo.shape)
geo_data = pd.merge(df_results, geo, on=['DEN_REG'])
print(geo_data.shape)
# Out:
# (42, 4) (20, 6)
# (42, 9)

# %%
geo_data = gpd.GeoDataFrame(geo_data, geometry = geo_data.geometry)
geo_data.geometry = geo_data.geometry.to_crs(epsg = 4326)
print(type(geo_data))
geo_data.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#   ITTER107        DEN_REG  SEXISTAT1      Value  COD_RIP  COD_REG
# 0     ITC1       Piemonte          1  2073845.0        1        1  \
# 1     ITC1       Piemonte          2  2182505.0        1        1
# 2     ITC2  Valle d'Aosta          1    60413.0        1        2
# 3     ITC2  Valle d'Aosta          2    62947.0        1        2
# 4    ITC20  Valle d'Aosta          1    60413.0        1        2
#
#      Shape_Leng    Shape_Area
# 0  1.236800e+06  2.539388e+10  \
# 1  1.236800e+06  2.539388e+10
# 2  3.109681e+05  3.258838e+09
# 3  3.109681e+05  3.258838e+09
# 4  3.109681e+05  3.258838e+09
#
#                                             geometry
# 0  POLYGON ((8.44976 46.46176, 8.46176 46.45081, ...
# 1  POLYGON ((8.44976 46.46176, 8.46176 46.45081, ...
# 2  POLYGON ((7.58857 45.97075, 7.58981 45.97073, ...
# 3  POLYGON ((7.58857 45.97075, 7.58981 45.97073, ...
# 4  POLYGON ((7.58857 45.97075, 7.58981 45.97073, ...

# %%
geo_data.to_file(processed / 'geo_data2.geojson', driver='GeoJSON')

# %%
print('Vane')
